# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-snilpn5u
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-snilpn5u
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.16.0+cu118)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=89b8598e9eb8b7dd0e6d48364f13e2f31007b44119dccbde56fbae96c63dd193
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5z1pkkr4/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.1.3

# %%
# from google.colab import files
# files.upload()

from google.colab import drive
drive.mount('/content/gdrive')

# !unzip /content/gdrive/MyDrive/DL/100-bird-species.zip -d /content/100-bird-species
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/120.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/121.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/122.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/123.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/124.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/125.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/126.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/127.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/128.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/129.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/130.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/131.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/132.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/133.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/134.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/135.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/136.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/137.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/138.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/139.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/140.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/141.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/142.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/143.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/144.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/145.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/146.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/147.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/148.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/149.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/150.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/151.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/152.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/153.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/154.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/155.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/156.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/157.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/158.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/159.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/160.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/161.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/162.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/163.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/164.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/165.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/166.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/167.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/168.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/169.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/170.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/171.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/172.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/173.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/174.jpg
#   inflating: /content/100-bird-species/train/WHITE TAILED TROPIC/175.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/001.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/002.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/003.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/004.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/005.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/006.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/007.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/008.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/009.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/010.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/011.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/012.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/013.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/014.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/015.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/016.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/017.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/018.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/019.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/020.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/021.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/022.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/023.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/024.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/025.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/026.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/027.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/028.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/029.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/030.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/031.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/032.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/033.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/034.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/035.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/036.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/037.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/038.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/039.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/040.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/041.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/042.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/043.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/044.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/045.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/046.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/047.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/048.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/049.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/050.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/051.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/052.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/053.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/054.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/055.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/056.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/057.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/058.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/059.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/060.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/061.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/062.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/063.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/064.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/065.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/066.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/067.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/068.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/069.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/070.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/071.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/072.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/073.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/074.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/075.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/076.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/077.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/078.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/079.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/080.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/081.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/082.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/083.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/084.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/085.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/086.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/087.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/088.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/089.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/090.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/091.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/092.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/093.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/094.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/095.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/096.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/097.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/098.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/099.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/100.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/101.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/102.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/103.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/104.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/105.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/106.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/107.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/108.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/109.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/110.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/111.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/112.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/113.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/114.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/115.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/116.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/117.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/118.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/119.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/120.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/121.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/122.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/123.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/124.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/125.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/126.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/127.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/128.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/129.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/130.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/131.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/132.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/133.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/134.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/135.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/136.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/137.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/138.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/139.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/140.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/141.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/142.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/143.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/144.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/145.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/146.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/147.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/148.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/149.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/150.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/151.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/152.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/153.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/154.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/155.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/156.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/157.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/158.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/159.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/160.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/161.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/162.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/163.jpg
#   inflating: /content/100-bird-species/train/WHITE THROATED BEE EATER/164.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/001.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/002.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/003.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/004.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/005.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/006.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/007.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/008.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/009.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/010.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/011.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/012.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/013.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/014.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/015.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/016.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/017.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/018.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/019.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/020.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/021.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/022.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/023.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/024.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/025.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/026.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/027.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/028.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/029.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/030.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/031.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/032.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/033.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/034.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/035.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/036.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/037.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/038.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/039.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/040.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/041.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/042.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/043.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/044.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/045.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/046.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/047.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/048.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/049.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/050.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/051.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/052.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/053.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/054.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/055.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/056.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/057.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/058.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/059.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/060.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/061.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/062.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/063.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/064.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/065.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/066.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/067.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/068.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/069.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/070.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/071.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/072.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/073.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/074.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/075.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/076.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/077.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/078.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/079.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/080.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/081.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/082.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/083.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/084.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/085.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/086.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/087.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/088.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/089.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/090.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/091.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/092.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/093.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/094.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/095.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/096.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/097.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/098.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/099.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/100.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/101.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/102.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/103.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/104.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/105.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/106.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/107.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/108.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/109.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/110.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/111.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/112.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/113.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/114.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/115.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/116.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/117.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/118.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/119.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/120.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/121.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/122.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/123.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/124.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/125.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/126.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/127.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/128.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/129.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/130.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/131.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/132.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/133.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/134.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/135.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/136.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/137.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/138.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/139.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/140.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/141.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/142.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/143.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/144.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/145.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/146.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/147.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/148.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/149.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/150.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/151.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/152.jpg
#   inflating: /content/100-bird-species/train/WILD TURKEY/153.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/001.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/002.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/003.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/004.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/005.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/006.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/007.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/008.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/009.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/010.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/011.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/012.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/013.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/014.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/015.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/016.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/017.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/018.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/019.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/020.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/021.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/022.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/023.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/024.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/025.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/026.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/027.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/028.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/029.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/030.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/031.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/032.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/033.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/034.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/035.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/036.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/037.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/038.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/039.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/040.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/041.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/042.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/043.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/044.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/045.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/046.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/047.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/048.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/049.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/050.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/051.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/052.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/053.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/054.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/055.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/056.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/057.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/058.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/059.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/060.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/061.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/062.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/063.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/064.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/065.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/066.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/067.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/068.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/069.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/070.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/071.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/072.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/073.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/074.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/075.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/076.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/077.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/078.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/079.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/080.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/081.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/082.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/083.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/084.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/085.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/086.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/087.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/088.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/089.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/090.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/091.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/092.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/093.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/094.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/095.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/096.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/097.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/098.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/099.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/100.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/101.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/102.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/103.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/104.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/105.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/106.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/107.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/108.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/109.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/110.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/111.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/112.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/113.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/114.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/115.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/116.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/117.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/118.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/119.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/120.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/121.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/122.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/123.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/124.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/125.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/126.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/127.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/128.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/129.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/130.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/131.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/132.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/133.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/134.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/135.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/136.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/137.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/138.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/139.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/140.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/141.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/142.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/143.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/144.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/145.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/146.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/147.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/148.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/149.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/150.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/151.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/152.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/153.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/154.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/155.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/156.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/157.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/158.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/159.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/160.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/161.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/162.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/163.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/164.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/165.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/166.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/167.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/168.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/169.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/170.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/171.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/172.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/173.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/174.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/175.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/176.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/177.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/178.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/179.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/180.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/181.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/182.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/183.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/184.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/185.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/186.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/187.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/188.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/189.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/190.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/191.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/192.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/193.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/194.jpg
#   inflating: /content/100-bird-species/train/WILLOW PTARMIGAN/195.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/001.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/002.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/003.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/004.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/005.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/006.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/007.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/008.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/009.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/010.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/011.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/012.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/013.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/014.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/015.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/016.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/017.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/018.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/019.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/020.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/021.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/022.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/023.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/024.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/025.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/026.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/027.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/028.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/029.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/030.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/031.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/032.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/033.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/034.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/035.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/036.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/037.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/038.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/039.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/040.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/041.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/042.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/043.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/044.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/045.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/046.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/047.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/048.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/049.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/050.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/051.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/052.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/053.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/054.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/055.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/056.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/057.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/058.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/059.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/060.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/061.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/062.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/063.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/064.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/065.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/066.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/067.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/068.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/069.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/070.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/071.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/072.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/073.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/074.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/075.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/076.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/077.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/078.jpg
#   inflating: /content/100-bird-species/train/WILSONS BIRD OF PARADISE/079.jpg
# ...
#   inflating: /content/100-bird-species/valid/TIT MOUSE/3.jpg
#   inflating: /content/100-bird-species/valid/TIT MOUSE/4.jpg
#   inflating: /content/100-bird-species/valid/TIT MOUSE/5.jpg
#   inflating: /content/100-bird-species/valid/TOUCHAN/1.jpg
#   inflating: /content/100-bird-species/valid/TOUCHAN/2.jpg
#   inflating: /content/100-bird-species/valid/TOUCHAN/3.jpg
#   inflating: /content/100-bird-species/valid/TOUCHAN/4.jpg
#   inflating: /content/100-bird-species/valid/TOUCHAN/5.jpg
#   inflating: /content/100-bird-species/valid/TOWNSENDS WARBLER/1.jpg
#   inflating: /content/100-bird-species/valid/TOWNSENDS WARBLER/2.jpg
#   inflating: /content/100-bird-species/valid/TOWNSENDS WARBLER/3.jpg
#   inflating: /content/100-bird-species/valid/TOWNSENDS WARBLER/4.jpg
#   inflating: /content/100-bird-species/valid/TOWNSENDS WARBLER/5.jpg
#   inflating: /content/100-bird-species/valid/TREE SWALLOW/1.jpg
#   inflating: /content/100-bird-species/valid/TREE SWALLOW/2.jpg
#   inflating: /content/100-bird-species/valid/TREE SWALLOW/3.jpg
#   inflating: /content/100-bird-species/valid/TREE SWALLOW/4.jpg
#   inflating: /content/100-bird-species/valid/TREE SWALLOW/5.jpg
#   inflating: /content/100-bird-species/valid/TRICOLORED BLACKBIRD/1.jpg
#   inflating: /content/100-bird-species/valid/TRICOLORED BLACKBIRD/2.jpg
#   inflating: /content/100-bird-species/valid/TRICOLORED BLACKBIRD/3.jpg
#   inflating: /content/100-bird-species/valid/TRICOLORED BLACKBIRD/4.jpg
#   inflating: /content/100-bird-species/valid/TRICOLORED BLACKBIRD/5.jpg
#   inflating: /content/100-bird-species/valid/TROPICAL KINGBIRD/1.jpg
#   inflating: /content/100-bird-species/valid/TROPICAL KINGBIRD/2.jpg
#   inflating: /content/100-bird-species/valid/TROPICAL KINGBIRD/3.jpg
#   inflating: /content/100-bird-species/valid/TROPICAL KINGBIRD/4.jpg
#   inflating: /content/100-bird-species/valid/TROPICAL KINGBIRD/5.jpg
#   inflating: /content/100-bird-species/valid/TRUMPTER SWAN/1.jpg
#   inflating: /content/100-bird-species/valid/TRUMPTER SWAN/2.jpg
#   inflating: /content/100-bird-species/valid/TRUMPTER SWAN/3.jpg
#   inflating: /content/100-bird-species/valid/TRUMPTER SWAN/4.jpg
#   inflating: /content/100-bird-species/valid/TRUMPTER SWAN/5.jpg
#   inflating: /content/100-bird-species/valid/TURKEY VULTURE/1.jpg
#   inflating: /content/100-bird-species/valid/TURKEY VULTURE/2.jpg
#   inflating: /content/100-bird-species/valid/TURKEY VULTURE/3.jpg
#   inflating: /content/100-bird-species/valid/TURKEY VULTURE/4.jpg
#   inflating: /content/100-bird-species/valid/TURKEY VULTURE/5.jpg
#   inflating: /content/100-bird-species/valid/TURQUOISE MOTMOT/1.jpg
#   inflating: /content/100-bird-species/valid/TURQUOISE MOTMOT/2.jpg
#   inflating: /content/100-bird-species/valid/TURQUOISE MOTMOT/3.jpg
#   inflating: /content/100-bird-species/valid/TURQUOISE MOTMOT/4.jpg
#   inflating: /content/100-bird-species/valid/TURQUOISE MOTMOT/5.jpg
#   inflating: /content/100-bird-species/valid/UMBRELLA BIRD/1.jpg
#   inflating: /content/100-bird-species/valid/UMBRELLA BIRD/2.jpg
#   inflating: /content/100-bird-species/valid/UMBRELLA BIRD/3.jpg
#   inflating: /content/100-bird-species/valid/UMBRELLA BIRD/4.jpg
#   inflating: /content/100-bird-species/valid/UMBRELLA BIRD/5.jpg
#   inflating: /content/100-bird-species/valid/VARIED THRUSH/1.jpg
#   inflating: /content/100-bird-species/valid/VARIED THRUSH/2.jpg
#   inflating: /content/100-bird-species/valid/VARIED THRUSH/3.jpg
#   inflating: /content/100-bird-species/valid/VARIED THRUSH/4.jpg
#   inflating: /content/100-bird-species/valid/VARIED THRUSH/5.jpg
#   inflating: /content/100-bird-species/valid/VEERY/1.jpg
#   inflating: /content/100-bird-species/valid/VEERY/2.jpg
#   inflating: /content/100-bird-species/valid/VEERY/3.jpg
#   inflating: /content/100-bird-species/valid/VEERY/4.jpg
#   inflating: /content/100-bird-species/valid/VEERY/5.jpg
#   inflating: /content/100-bird-species/valid/VENEZUELIAN TROUPIAL/1.jpg
#   inflating: /content/100-bird-species/valid/VENEZUELIAN TROUPIAL/2.jpg
#   inflating: /content/100-bird-species/valid/VENEZUELIAN TROUPIAL/3.jpg
#   inflating: /content/100-bird-species/valid/VENEZUELIAN TROUPIAL/4.jpg
#   inflating: /content/100-bird-species/valid/VENEZUELIAN TROUPIAL/5.jpg
#   inflating: /content/100-bird-species/valid/VERDIN/1.jpg
#   inflating: /content/100-bird-species/valid/VERDIN/2.jpg
#   inflating: /content/100-bird-species/valid/VERDIN/3.jpg
#   inflating: /content/100-bird-species/valid/VERDIN/4.jpg
#   inflating: /content/100-bird-species/valid/VERDIN/5.jpg
#   inflating: /content/100-bird-species/valid/VERMILION FLYCATHER/1.jpg
#   inflating: /content/100-bird-species/valid/VERMILION FLYCATHER/2.jpg
#   inflating: /content/100-bird-species/valid/VERMILION FLYCATHER/3.jpg
#   inflating: /content/100-bird-species/valid/VERMILION FLYCATHER/4.jpg
#   inflating: /content/100-bird-species/valid/VERMILION FLYCATHER/5.jpg
#   inflating: /content/100-bird-species/valid/VICTORIA CROWNED PIGEON/1.jpg
#   inflating: /content/100-bird-species/valid/VICTORIA CROWNED PIGEON/2.jpg
#   inflating: /content/100-bird-species/valid/VICTORIA CROWNED PIGEON/3.jpg
#   inflating: /content/100-bird-species/valid/VICTORIA CROWNED PIGEON/4.jpg
#   inflating: /content/100-bird-species/valid/VICTORIA CROWNED PIGEON/5.jpg
#   inflating: /content/100-bird-species/valid/VIOLET BACKED STARLING/1.jpg
#   inflating: /content/100-bird-species/valid/VIOLET BACKED STARLING/2.jpg
#   inflating: /content/100-bird-species/valid/VIOLET BACKED STARLING/3.jpg
#   inflating: /content/100-bird-species/valid/VIOLET BACKED STARLING/4.jpg
#   inflating: /content/100-bird-species/valid/VIOLET BACKED STARLING/5.jpg
#   inflating: /content/100-bird-species/valid/VIOLET CUCKOO/1.jpg
#   inflating: /content/100-bird-species/valid/VIOLET CUCKOO/2.jpg
#   inflating: /content/100-bird-species/valid/VIOLET CUCKOO/3.jpg
#   inflating: /content/100-bird-species/valid/VIOLET CUCKOO/4.jpg
#   inflating: /content/100-bird-species/valid/VIOLET CUCKOO/5.jpg
#   inflating: /content/100-bird-species/valid/VIOLET GREEN SWALLOW/1.jpg
#   inflating: /content/100-bird-species/valid/VIOLET GREEN SWALLOW/2.jpg
#   inflating: /content/100-bird-species/valid/VIOLET GREEN SWALLOW/3.jpg
#   inflating: /content/100-bird-species/valid/VIOLET GREEN SWALLOW/4.jpg
#   inflating: /content/100-bird-species/valid/VIOLET GREEN SWALLOW/5.jpg
#   inflating: /content/100-bird-species/valid/VIOLET TURACO/1.jpg
#   inflating: /content/100-bird-species/valid/VIOLET TURACO/2.jpg
#   inflating: /content/100-bird-species/valid/VIOLET TURACO/3.jpg
#   inflating: /content/100-bird-species/valid/VIOLET TURACO/4.jpg
#   inflating: /content/100-bird-species/valid/VIOLET TURACO/5.jpg
#   inflating: /content/100-bird-species/valid/VISAYAN HORNBILL/1.jpg
#   inflating: /content/100-bird-species/valid/VISAYAN HORNBILL/2.jpg
#   inflating: /content/100-bird-species/valid/VISAYAN HORNBILL/3.jpg
#   inflating: /content/100-bird-species/valid/VISAYAN HORNBILL/4.jpg
#   inflating: /content/100-bird-species/valid/VISAYAN HORNBILL/5.jpg
#   inflating: /content/100-bird-species/valid/VULTURINE GUINEAFOWL/1.jpg
#   inflating: /content/100-bird-species/valid/VULTURINE GUINEAFOWL/2.jpg
#   inflating: /content/100-bird-species/valid/VULTURINE GUINEAFOWL/3.jpg
#   inflating: /content/100-bird-species/valid/VULTURINE GUINEAFOWL/4.jpg
#   inflating: /content/100-bird-species/valid/VULTURINE GUINEAFOWL/5.jpg
#   inflating: /content/100-bird-species/valid/WALL CREAPER/1.jpg
#   inflating: /content/100-bird-species/valid/WALL CREAPER/2.jpg
#   inflating: /content/100-bird-species/valid/WALL CREAPER/3.jpg
#   inflating: /content/100-bird-species/valid/WALL CREAPER/4.jpg
#   inflating: /content/100-bird-species/valid/WALL CREAPER/5.jpg
#   inflating: /content/100-bird-species/valid/WATTLED CURASSOW/1.jpg
#   inflating: /content/100-bird-species/valid/WATTLED CURASSOW/2.jpg
#   inflating: /content/100-bird-species/valid/WATTLED CURASSOW/3.jpg
#   inflating: /content/100-bird-species/valid/WATTLED CURASSOW/4.jpg
#   inflating: /content/100-bird-species/valid/WATTLED CURASSOW/5.jpg
#   inflating: /content/100-bird-species/valid/WATTLED LAPWING/1.jpg
#   inflating: /content/100-bird-species/valid/WATTLED LAPWING/2.jpg
#   inflating: /content/100-bird-species/valid/WATTLED LAPWING/3.jpg
#   inflating: /content/100-bird-species/valid/WATTLED LAPWING/4.jpg
#   inflating: /content/100-bird-species/valid/WATTLED LAPWING/5.jpg
#   inflating: /content/100-bird-species/valid/WHIMBREL/1.jpg
#   inflating: /content/100-bird-species/valid/WHIMBREL/2.jpg
#   inflating: /content/100-bird-species/valid/WHIMBREL/3.jpg
#   inflating: /content/100-bird-species/valid/WHIMBREL/4.jpg
#   inflating: /content/100-bird-species/valid/WHIMBREL/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE BREASTED WATERHEN/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE BREASTED WATERHEN/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE BREASTED WATERHEN/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE BREASTED WATERHEN/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE BREASTED WATERHEN/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE BROWED CRAKE/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE BROWED CRAKE/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE BROWED CRAKE/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE BROWED CRAKE/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE BROWED CRAKE/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE CHEEKED TURACO/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE CHEEKED TURACO/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE CHEEKED TURACO/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE CHEEKED TURACO/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE CHEEKED TURACO/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE CRESTED HORNBILL/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE CRESTED HORNBILL/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE CRESTED HORNBILL/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE CRESTED HORNBILL/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE CRESTED HORNBILL/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE EARED HUMMINGBIRD/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE EARED HUMMINGBIRD/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE EARED HUMMINGBIRD/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE EARED HUMMINGBIRD/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE EARED HUMMINGBIRD/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE NECKED RAVEN/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE NECKED RAVEN/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE NECKED RAVEN/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE NECKED RAVEN/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE NECKED RAVEN/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE TAILED TROPIC/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE TAILED TROPIC/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE TAILED TROPIC/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE TAILED TROPIC/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE TAILED TROPIC/5.jpg
#   inflating: /content/100-bird-species/valid/WHITE THROATED BEE EATER/1.jpg
#   inflating: /content/100-bird-species/valid/WHITE THROATED BEE EATER/2.jpg
#   inflating: /content/100-bird-species/valid/WHITE THROATED BEE EATER/3.jpg
#   inflating: /content/100-bird-species/valid/WHITE THROATED BEE EATER/4.jpg
#   inflating: /content/100-bird-species/valid/WHITE THROATED BEE EATER/5.jpg
#   inflating: /content/100-bird-species/valid/WILD TURKEY/1.jpg
#   inflating: /content/100-bird-species/valid/WILD TURKEY/2.jpg
#   inflating: /content/100-bird-species/valid/WILD TURKEY/3.jpg
#   inflating: /content/100-bird-species/valid/WILD TURKEY/4.jpg
#   inflating: /content/100-bird-species/valid/WILD TURKEY/5.jpg
#   inflating: /content/100-bird-species/valid/WILLOW PTARMIGAN/1.jpg
#   inflating: /content/100-bird-species/valid/WILLOW PTARMIGAN/2.jpg
#   inflating: /content/100-bird-species/valid/WILLOW PTARMIGAN/3.jpg
#   inflating: /content/100-bird-species/valid/WILLOW PTARMIGAN/4.jpg
#   inflating: /content/100-bird-species/valid/WILLOW PTARMIGAN/5.jpg
#   inflating: /content/100-bird-species/valid/WILSONS BIRD OF PARADISE/1.jpg
#   inflating: /content/100-bird-species/valid/WILSONS BIRD OF PARADISE/2.jpg
#   inflating: /content/100-bird-species/valid/WILSONS BIRD OF PARADISE/3.jpg
#   inflating: /content/100-bird-species/valid/WILSONS BIRD OF PARADISE/4.jpg
#   inflating: /content/100-bird-species/valid/WILSONS BIRD OF PARADISE/5.jpg
#   inflating: /content/100-bird-species/valid/WOOD DUCK/1.jpg
#   inflating: /content/100-bird-species/valid/WOOD DUCK/2.jpg
#   inflating: /content/100-bird-species/valid/WOOD DUCK/3.jpg
#   inflating: /content/100-bird-species/valid/WOOD DUCK/4.jpg
#   inflating: /content/100-bird-species/valid/WOOD DUCK/5.jpg
#   inflating: /content/100-bird-species/valid/WOOD THRUSH/1.jpg
#   inflating: /content/100-bird-species/valid/WOOD THRUSH/2.jpg
#   inflating: /content/100-bird-species/valid/WOOD THRUSH/3.jpg
#   inflating: /content/100-bird-species/valid/WOOD THRUSH/4.jpg
#   inflating: /content/100-bird-species/valid/WOOD THRUSH/5.jpg
#   inflating: /content/100-bird-species/valid/WOODLAND KINGFISHER/1.jpg
#   inflating: /content/100-bird-species/valid/WOODLAND KINGFISHER/2.jpg
#   inflating: /content/100-bird-species/valid/WOODLAND KINGFISHER/3.jpg
#   inflating: /content/100-bird-species/valid/WOODLAND KINGFISHER/4.jpg
#   inflating: /content/100-bird-species/valid/WOODLAND KINGFISHER/5.jpg
#   inflating: /content/100-bird-species/valid/WRENTIT/1.jpg
#   inflating: /content/100-bird-species/valid/WRENTIT/2.jpg
#   inflating: /content/100-bird-species/valid/WRENTIT/3.jpg
#   inflating: /content/100-bird-species/valid/WRENTIT/4.jpg
#   inflating: /content/100-bird-species/valid/WRENTIT/5.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BELLIED FLOWERPECKER/1.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BELLIED FLOWERPECKER/2.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BELLIED FLOWERPECKER/3.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BELLIED FLOWERPECKER/4.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BELLIED FLOWERPECKER/5.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BREASTED CHAT/1.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BREASTED CHAT/2.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BREASTED CHAT/3.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BREASTED CHAT/4.jpg
#   inflating: /content/100-bird-species/valid/YELLOW BREASTED CHAT/5.jpg
#   inflating: /content/100-bird-species/valid/YELLOW CACIQUE/1.jpg
#   inflating: /content/100-bird-species/valid/YELLOW CACIQUE/2.jpg
#   inflating: /content/100-bird-species/valid/YELLOW CACIQUE/3.jpg
#   inflating: /content/100-bird-species/valid/YELLOW CACIQUE/4.jpg
#   inflating: /content/100-bird-species/valid/YELLOW CACIQUE/5.jpg
#   inflating: /content/100-bird-species/valid/YELLOW HEADED BLACKBIRD/1.jpg
#   inflating: /content/100-bird-species/valid/YELLOW HEADED BLACKBIRD/2.jpg
#   inflating: /content/100-bird-species/valid/YELLOW HEADED BLACKBIRD/3.jpg
#   inflating: /content/100-bird-species/valid/YELLOW HEADED BLACKBIRD/4.jpg
#   inflating: /content/100-bird-species/valid/YELLOW HEADED BLACKBIRD/5.jpg
#   inflating: /content/100-bird-species/valid/ZEBRA DOVE/1.jpg
#   inflating: /content/100-bird-species/valid/ZEBRA DOVE/2.jpg
#   inflating: /content/100-bird-species/valid/ZEBRA DOVE/3.jpg
#   inflating: /content/100-bird-species/valid/ZEBRA DOVE/4.jpg
#   inflating: /content/100-bird-species/valid/ZEBRA DOVE/5.jpg

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import torchvision

import clip
from PIL import Image
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
clip_model, preprocess = clip.load("ViT-B/32", device=device)
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:04<00:00, 82.8MiB/s]

# %%
# Defining dataset path
data_dir = '/content/100-bird-species/'
train_dir = data_dir + 'train/'
valid_dir = data_dir + 'valid/'

# %%
# Defining train transform and val transform along with data
train_transform = transforms.Compose([
  # transforms.Resize((128, 128)),
  transforms.Resize((64, 64)),
  # transforms.Resize((32, 32)),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor()
])

val_transform = transforms.Compose([
  # transforms.Resize((128, 128)),
  transforms.Resize((64, 64)),
  # transforms.Resize((32, 32)),
  transforms.ToTensor()
])

# %%
#Creating dataset
train_dataset = ImageFolder(train_dir, transform=train_transform)
val_dataset = ImageFolder(valid_dir,transform=val_transform)

# %%
batch_size = 128
# Creating dataloader
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size, shuffle=True)

# %%
# Defining num of classes
num_classes = len(train_dataset.classes)
print(num_classes)
# Out:
# 525

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
# Pushing data to device
train_loader = DeviceDataLoader(train_loader, device)
valid_loader = DeviceDataLoader(valid_loader, device)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, images, labels):
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss

    def validation_step(self, images, labels):
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class BirdSpeciesCnnModel(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.clip = clip_model.visual
        self.network = nn.Sequential(
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes))

    def forward(self, xb):
        xb = self.clip(xb)
        return self.network(xb)

# %%
model = BirdSpeciesCnnModel()
model
# Out:
# BirdSpeciesCnnModel(
#   (clip): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): Sequential(
#         (0): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (network): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=525, bias=True)
#   )
# )

# %%
transform = transforms.ToPILImage()

# %%
from tqdm import tqdm
import copy

@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = list()
    for images, labels in tqdm(val_loader):
      new_images = []
      for i, image in enumerate(images):
        image_input = preprocess(transform(image)).unsqueeze(0).to(device)
        image_input = image_input.squeeze()
        new_images.append(np.asarray(image_input.cpu()))
      new_images = np.asarray(new_images)
      new_images = torch.from_numpy(new_images)
      new_images = new_images.to(device)
      labels = labels.to(device)
      outputs.append(model.validation_step(new_images, labels))
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %%
def fit(epochs, lr, model, train_loader, val_loader, weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    optimizer = opt_func(model.parameters(), lr, weight_decay=weight_decay)
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, lr, epochs=epochs, steps_per_epoch=len(train_loader))
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_losses = []
        lrs = []
        for images, labels in tqdm(train_loader):
            new_images = []
            for i, image in enumerate(images):
              image_input = preprocess(transform(image)).unsqueeze(0).to(device)
              image_input = image_input.squeeze()
              new_images.append(np.asarray(image_input.cpu()))
            new_images = np.asarray(new_images)
            new_images = torch.from_numpy(new_images)

            new_images = new_images.to(device)
            loss = model.training_step(new_images, labels)
            train_losses.append(loss)
            loss.backward()
            # Gradient clipping
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            optimizer.step()
            optimizer.zero_grad()
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
def initialize_weights(m):
  if isinstance(m, nn.Conv2d):
      nn.init.kaiming_uniform_(m.weight.data,nonlinearity='relu')
      if m.bias is not None:
          nn.init.constant_(m.bias.data, 0)
  elif isinstance(m, nn.BatchNorm2d):
      nn.init.constant_(m.weight.data, 1)
      nn.init.constant_(m.bias.data, 0)
  elif isinstance(m, nn.Linear):
      nn.init.kaiming_uniform_(m.weight.data)
      nn.init.constant_(m.bias.data, 0)

model=BirdSpeciesCnnModel()
model.apply(initialize_weights)
# Out:
# BirdSpeciesCnnModel(
#   (clip): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): Sequential(
#         (0): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): ResidualAttentionBlock(
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): QuickGELU()
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (network): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=525, bias=True)
#   )
# )

# %%
train_dl = DeviceDataLoader(train_loader, device)
val_dl = DeviceDataLoader(valid_loader, device)
to_device(model, device)
epochs = 10
max_lr = 0.1
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %%
if torch.cuda.is_available():
  model = model.type(torch.cuda.FloatTensor)
history = fit(epochs, max_lr, model, train_loader, valid_loader, weight_decay, grad_clip, opt_func)
# Out:
# 100%|██████████| 662/662 [09:00<00:00,  1.22it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.80it/s]
# Epoch [0], last_lr: 0.02796, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [09:00<00:00,  1.22it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.79it/s]
# Epoch [1], last_lr: 0.07598, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [08:58<00:00,  1.23it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.86it/s]
# Epoch [2], last_lr: 0.10000, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [08:59<00:00,  1.23it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.83it/s]
# Epoch [3], last_lr: 0.09505, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [09:09<00:00,  1.21it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.75it/s]
# Epoch [4], last_lr: 0.08117, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [09:10<00:00,  1.20it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.78it/s]
# Epoch [5], last_lr: 0.06113, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [09:17<00:00,  1.19it/s]
# 100%|██████████| 21/21 [00:12<00:00,  1.71it/s]
# Epoch [6], last_lr: 0.03887, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [09:13<00:00,  1.20it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.82it/s]
# Epoch [7], last_lr: 0.01883, train_loss: nan, val_loss: nan, val_acc: 0.0019
# 100%|██████████| 662/662 [09:08<00:00,  1.21it/s]
# 100%|██████████| 21/21 [00:11<00:00,  1.80it/s]
# Epoch [8], last_lr: 0.00495, train_loss: nan, val_loss: nan, val_acc: 0.0019
#  12%|█▏        | 78/662 [01:05<08:09,  1.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-552ae94033e6> in <cell line: 3>()
#       1 if torch.cuda.is_available():
#       2   model = model.type(torch.cuda.FloatTensor)
# ----> 3 history = fit(epochs, max_lr, model, train_loader, valid_loader, weight_decay, grad_clip, opt_func)
#
# <ipython-input-20-570b61e0127c> in fit(epochs, lr, model, train_loader, val_loader, weight_decay, grad_clip, opt_func)
#      21             loss = model.training_step(new_images, labels)
#      22             train_losses.append(loss)
# ---> 23             loss.backward()
#      24             # Gradient clipping
#      25             if grad_clip:
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.')

# %%
plot_accuracies(history)

# %%
plot_losses(history)

# %%
plot_lrs(history)

# %%
test_dataset = ImageFolder(data_dir+'/test', transform=val_transform)
test_loader = DeviceDataLoader(DataLoader(test_dataset, batch_size*2), device)
result = evaluate(model, test_loader)
result

# %%
torch.save(model.state_dict(), 'Clip04.pth')
